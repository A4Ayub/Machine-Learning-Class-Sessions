# %% [markdown]
# # Twitter Job Hunter Modelling Notebook
# by A4Ayub Hands-On Labs (http://www.a4ayub.me)

# %% [markdown]
# ## Background Information

# %% [markdown]
# On 15th July 2020 we , A4Ayub Hands-On Labd started a new Hands-On Project Based Learning path dubbed  **build a twitter job hunting chatbot** after successful registration of the below participants:
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## The Data

# %% [markdown]
# **On Day #1**, we learnt about how to scrap data from twitter and everyone was tasked to practice and scrape job related tweets from twitter as a contribution to the crowdsourced data as we learn and we collectively generated the dataset that is to be used to model the chatbot responses.
#
# We collected approximately 29,000 job related tweets from twitter. Thanks to the contribution of the participants.

# %% [markdown]
# **On Day #2**, we will cover data cleaning. We shall learn data cleaning and wrangling techniques as a way of preparing the data for visualisation and this notebook will be updated with what each person will have learnt in class.

# %%
# Import the required libraries
import re
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import string
import nltk
import warnings

import string

from wordcloud import WordCloud,STOPWORDS

from bs4 import BeautifulSoup

warnings.filterwarnings("ignore", category=DeprecationWarning)

# %matplotlib inline

# %%
# import the data
twitter_df = pd.read_csv("./datasets/twitter-job-hunter-chatbot.csv",engine="python", parse_dates=True, index_col=0);

# %%
# check for the datatypes
twitter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29674 entries, 2020-07-18 11:46:00 to 2020-06-27 00:09:00
# Data columns (total 8 columns):
# Text               29674 non-null object
# Source             29460 non-null object
# harsh tag          4721 non-null object
# Favourite Count    29142 non-null float64
# Retweets           27122 non-null float64
# 6                  23075 non-null float64
# 7                  23075 non-null float64
# submitter_name     29674 non-null object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
twitter_df.sample(5)
# Out:
#                                                                         Text  \
# Datetime
# 2020-06-29 16:48:00        #IkoKaziKE #IkoKazi #supportmyhustle https://t...
# 2020-07-17 13:07:00        @ashes_glow Follow @Seekruit_  for updates on ...
# 2020-06-30 05:50:30+00:00  Vice President of Sales â€“ Central Africa is ...
# 2020-07-09 05:43:12+00:00  An excellent opportunity has arisen for a Corp...
# 2020-07-17 16:49:00        @PullmanComley @CT_HBA Congratulations Andres\...
#
#                                     Source harsh tag  Favourite Count  \
# Datetime
# 2020-06-29 16:48:00                  cessy         1              1.0
# 2020-07-17 13:07:00        Twitter Web App       NaN              0.0
# 2020-06-30 05:50:30+00:00       job_zambia       NaN              1.0
# 2020-07-09 05:43:12+00:00    vacancycentre       NaN              0.0
# 2020-07-17 16:49:00        Twitter Web App       NaN              0.0
#
#                            Retweets    6    7   submitter_name
# Datetime
# 2020-06-29 16:48:00             NaN  NaN  NaN  Kennedy Njoroge
# 2020-07-17 13:07:00             0.0  NaN  NaN   David Mwambali
# 2020-06-30 05:50:30+00:00       0.0  0.0  0.0       Eric Nzivo
# 2020-07-09 05:43:12+00:00       0.0  0.0  0.0       Eric Nzivo
# 2020-07-17 16:49:00             0.0  NaN  NaN   David Mwambali

# %%
# check for any null values
twitter_df.isnull().values.any()
# Out:
# True

# %%
# Check for null values in the text column
twitter_df["Text"].isnull().values.any()
# Out:
# False

# %%
# Check for null values in the text column
twitter_df["Source"].isnull().values.any()
# Out:
# True

# %%
# Only consider the tweets that the source is not null
twitter_df = twitter_df[~twitter_df["Source"].isnull()]
twitter_df["Source"].isnull().values.any()
# Out:
# False

# %%
# derive a new dtaframe having the fields that we require
twitter_df = twitter_df[["Text","Source"]]
twitter_df.sample(5)
# Out:
#                                                                         Text  \
# Datetime
# 2020-07-14 17:25:03+00:00  Work with us - Chief executive officer #vacanc...
# 2020-06-16 07:30:40+00:00   WE ARE HIRING! Come and join our designer tea...
# 2020-07-09 22:04:18+00:00  Looking for more job opportunities? Check out ...
# 2020-07-02 22:00:14+00:00  Looking for more job opportunities? Check out ...
# 2020-07-15 17:38:04+00:00  CommScope is Hiring | Mechanical Drafter | Dip...
#
#                                     Source
# Datetime
# 2020-07-14 17:25:03+00:00      HWGateshead
# 2020-06-16 07:30:40+00:00     AidilMokhtar
# 2020-07-09 22:04:18+00:00        KaziQuest
# 2020-07-02 22:00:14+00:00        KaziQuest
# 2020-07-15 17:38:04+00:00  MechanicalRockz

# %% [markdown]
# ### Some cleaning requirements

# %% [markdown]
# 1. Get rid of punctuations, numbers and even special characters
# 2. stop words
# 3. tokenization
# 4. stemming

# %% [markdown]
# ### Custom functions

# %%
# Perform Data Cleaning on the text
def cleaning(message):
    import nltk
    
    # 1. Remove HTML.
    html_text = BeautifulSoup(message,"html.parser").get_text()
    
    # 2. Remove punctuations
    letters=[words for words in html_text if words not in string.punctation]
        
    # 4. Convert to lower case.
    letters = letters.lower()
    
    # 5. Tokenize.
    tokens = nltk.word_tokenize(letters)
    
    # 6. Convert the stopwords list to "set" data type.
    stops = set(nltk.corpus.stopwords.words("english"))
    
    # 7. Remove stop words. 
    words = [w for w in tokens if not w in stops]
    
    # 8. Stemming
    words = [nltk.stem.SnowballStemmer('english').stem(w) for w in words]
    
    # 9. Join the words back into one string separated by space, and return the result.
    return " ".join(tokens)

# %%
# Create a word cloud
def cloud(data,backgroundcolor = 'white', width = 800, height = 600):
    wordcloud = WordCloud(stopwords = STOPWORDS, background_color = backgroundcolor,
                         width = width, height = height).generate(data)
    plt.figure(figsize = (15, 10))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
# function to collect hashtags
def hashtag_extract(x):
    hashtags = []
    # Loop over the words in the tweet
    for i in x:
        ht = re.findall(r"#(\w+)", i)
        hashtags.append(ht)

    return hashtags

# %% [markdown]
# ### Some Questions

# %% [markdown]
# 1. Common words in the entire dataset
# 2. Frequency of Source
# 3. Common words by Source
# 4. How many hash tags are there in a tweet
# 5. What are the general trends
# 6. Which trendscan we observe per source

# %%
# apply the cleaning function
twitter_df["clean_tweet"] = twitter_df['Text'].apply(cleaning)
# Out:
# E:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:335: UserWarning: "https://t.co/p8iPUejSpY
#
# #IkoKaziKE" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup

# %%
# sample the twitter_df
twitter_df.sample(5)
# Out:
#                                                                         Text  \
# Datetime
# 2020-07-15 08:03:23+00:00  Nairobi Vacancies WhatsApp Group - https://opp...
# 2020-07-18 19:37:24+00:00  ServiceNow is looking for: Federal Mission Acc...
# 2020-07-18 16:38:19+00:00  Premise Health is looking for: Registered Nurs...
# 2020-07-15 09:12:15+00:00  I'm looking for such trucks to work for a cons...
# 2020-07-17 18:15:00        #newjob alert! We are looking for a #Bartender...
#
#                                     Source  \
# Datetime
# 2020-07-15 08:03:23+00:00     Simon_Ingari
# 2020-07-18 19:37:24+00:00  DanielWaite_NOW
# 2020-07-18 16:38:19+00:00   premisejessyka
# 2020-07-15 09:12:15+00:00     Antione_Vice
# 2020-07-17 18:15:00              TweetDeck
#
#                                                                  clean_tweet
# Datetime
# 2020-07-15 08:03:23+00:00  nairobi vacancies whatsapp group - https : //o...
# 2020-07-18 19:37:24+00:00  servicenow is looking for : federal mission ac...
# 2020-07-18 16:38:19+00:00  premise health is looking for : registered nur...
# 2020-07-15 09:12:15+00:00  i 'm looking for such trucks to work for a con...
# 2020-07-17 18:15:00        # newjob alert ! we are looking for a # barten...

# %%
# display the word cloud
cloud(' '.join(twitter_df['clean_tweet']))

# %%
# removing punctuations
